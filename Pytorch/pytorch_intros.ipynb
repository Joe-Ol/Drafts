# %% [markdown]
# <a href="https://colab.research.google.com/github/JoeOlang/Drafts/blob/master/Pytorch/pytorch_intros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch==1.8.1+cpu torchvision==0.9.1+cpu torchaudio===0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 169.1MB 82kB/s
# ...
#      |████████████████████████████████| 13.4MB 334kB/s
# ...
#      |████████████████████████████████| 1.9MB 4.5MB/s
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# ...

# %%
import torch

# %%
data = [[1,2],[3,4]]

x_data = torch.tensor(data)

print(x*y)
# Out:
# tensor([10.,  3.])

# %%
x = torch.zeros([2,5])

# %% [markdown]
# print(x)

# %%
y = torch.rand([2, 5])

# %% [markdown]
# print(y)

# %%
y = y.view([1,10])
