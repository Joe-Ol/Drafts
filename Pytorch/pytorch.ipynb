# %% [markdown]
# <a href="https://colab.research.google.com/github/JoeOlang/Drafts/blob/master/Pytorch/pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch==1.8.1+cu102 torchvision==0.9.1+cu102 torchaudio===0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 804.1MB 21kB/s
# ...
#      |████████████████████████████████| 17.3MB 173kB/s
# ...
#      |████████████████████████████████| 1.9MB 5.0MB/s
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# ...

# %%
import torch
import numpy as np

# %%
data = [[1,2],[3,4]]

x_data = torch.tensor(data)

print(x_data)
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
x_ones = torch.ones_like(x_data)
print(x_ones)
# Out:
# tensor([[1, 1],
#         [1, 1]])

# %%
shape = (3, 4)
rand_tensor = torch.rand(shape)
ones_tensor = torch.ones(shape)
zerso_tensor = torch.zeros(shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6eaab4804f9c> in <module>()
#       1 shape = (3, 4)
# ----> 2 rand_tensor = torch.rand(shape)
#       3 ones_tensor = torch.ones(shape)
#       4 zerso_tensor = torch.zeros(shape)
#
# NameError: name 'torch' is not defined

# %%
print(rand_tensor)
print(ones_tensor)
print(zeros_tensor)
